# %%
usr_tuple = tuple(input("Enter the elements separate by space: ").split())

print(usr_tuple)
# Out:
# ('4', '5', '6', '98')

# %%
print(set(["Hello", "How", "Hello" ,"Are"]))
# Out:
# {'Hello', 'Are', 'How'}

# %%
ti = sorted(tuple(["Hello", "How" ,"Are"]))

a = sorted(tuple((set(ti))))

string = "hello".split()
print(ti)
print(a)

print(ti == a)
print(string)
# Out:
# ['Are', 'Hello', 'How']
# ['Are', 'Hello', 'How']
# True
# ['hello']
